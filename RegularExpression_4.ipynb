# %%
text_to_search="""
                 abcdefghijklmnopqrstuvwxyz
                  ABCDEFGHIJKLMNOPQRSTUVWXYZ
                  1234567890
                  Ha Haha

                  MetaCharacters (Need to be escaped):
                  .^$*+?{}[]\|()

                  coreyms.com
                  321-555-4321
                  321-555-1234

                  Mr.Schafer
                  Mr Smith
                  Ms Davis
                  Mrs. Robinson
                  Mr. T
            """
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\|'
# <>:8: SyntaxWarning: invalid escape sequence '\|'
# /tmp/ipykernel_12352/111314781.py:8: SyntaxWarning: invalid escape sequence '\|'
#   .^$*+?{}[]\|()

# %%
import re

# %% [markdown]
# All character except Newline character

# %%
pattern=re.compile(r".")
matches =re.finditer(pattern,text_to_search)
for match in matches:
  print(match)
# Out:
# <re.Match object; span=(1, 2), match=' '>
# <re.Match object; span=(2, 3), match=' '>
# <re.Match object; span=(3, 4), match=' '>
# <re.Match object; span=(4, 5), match=' '>
# <re.Match object; span=(5, 6), match=' '>
# <re.Match object; span=(6, 7), match=' '>
# <re.Match object; span=(7, 8), match=' '>
# <re.Match object; span=(8, 9), match=' '>
# <re.Match object; span=(9, 10), match=' '>
# <re.Match object; span=(10, 11), match=' '>
# <re.Match object; span=(11, 12), match=' '>
# <re.Match object; span=(12, 13), match=' '>
# <re.Match object; span=(13, 14), match=' '>
# <re.Match object; span=(14, 15), match=' '>
# <re.Match object; span=(15, 16), match=' '>
# <re.Match object; span=(16, 17), match=' '>
# <re.Match object; span=(17, 18), match=' '>
# <re.Match object; span=(18, 19), match='a'>
# <re.Match object; span=(19, 20), match='b'>
# <re.Match object; span=(20, 21), match='c'>
# <re.Match object; span=(21, 22), match='d'>
# <re.Match object; span=(22, 23), match='e'>
# ...

# %% [markdown]
# Digits between 0-9

# %%
import re

# %%
pattern=re.compile(r"\d")
matches=re.finditer(pattern,text_to_search)
for match in matches:
  print(match)
# Out:
# <re.Match object; span=(108, 109), match='1'>
# <re.Match object; span=(109, 110), match='2'>
# <re.Match object; span=(110, 111), match='3'>
# <re.Match object; span=(111, 112), match='4'>
# <re.Match object; span=(112, 113), match='5'>
# <re.Match object; span=(113, 114), match='6'>
# <re.Match object; span=(114, 115), match='7'>
# <re.Match object; span=(115, 116), match='8'>
# <re.Match object; span=(116, 117), match='9'>
# <re.Match object; span=(117, 118), match='0'>
# <re.Match object; span=(301, 302), match='3'>
# <re.Match object; span=(302, 303), match='2'>
# <re.Match object; span=(303, 304), match='1'>
# <re.Match object; span=(305, 306), match='5'>
# <re.Match object; span=(306, 307), match='5'>
# <re.Match object; span=(307, 308), match='5'>
# <re.Match object; span=(309, 310), match='4'>
# <re.Match object; span=(310, 311), match='3'>
# <re.Match object; span=(311, 312), match='2'>
# <re.Match object; span=(312, 313), match='1'>
# ...

# %% [markdown]
# Matches that are not Digits

# %%
import re

# %%
pattern=re.compile(r"\D")
matches=re.finditer(pattern,text_to_search)
for match in matches:
  print(match)
# Out:
# <re.Match object; span=(0, 1), match='\n'>
# <re.Match object; span=(1, 2), match=' '>
# <re.Match object; span=(2, 3), match=' '>
# <re.Match object; span=(3, 4), match=' '>
# <re.Match object; span=(4, 5), match=' '>
# <re.Match object; span=(5, 6), match=' '>
# <re.Match object; span=(6, 7), match=' '>
# <re.Match object; span=(7, 8), match=' '>
# <re.Match object; span=(8, 9), match=' '>
# <re.Match object; span=(9, 10), match=' '>
# <re.Match object; span=(10, 11), match=' '>
# <re.Match object; span=(11, 12), match=' '>
# <re.Match object; span=(12, 13), match=' '>
# <re.Match object; span=(13, 14), match=' '>
# <re.Match object; span=(14, 15), match=' '>
# <re.Match object; span=(15, 16), match=' '>
# <re.Match object; span=(16, 17), match=' '>
# <re.Match object; span=(17, 18), match=' '>
# <re.Match object; span=(18, 19), match='a'>
# <re.Match object; span=(19, 20), match='b'>
# <re.Match object; span=(20, 21), match='c'>
# <re.Match object; span=(21, 22), match='d'>
# ...

# %% [markdown]
# Matches Digits,Uppercase,Lowercase and Underscore

# %%
import re

# %%
pattern=re.compile(r"\w")
matches=re.finditer(pattern,text_to_search)
for match in matches:
  print(match)
# Out:
# <re.Match object; span=(18, 19), match='a'>
# <re.Match object; span=(19, 20), match='b'>
# <re.Match object; span=(20, 21), match='c'>
# <re.Match object; span=(21, 22), match='d'>
# <re.Match object; span=(22, 23), match='e'>
# <re.Match object; span=(23, 24), match='f'>
# <re.Match object; span=(24, 25), match='g'>
# <re.Match object; span=(25, 26), match='h'>
# <re.Match object; span=(26, 27), match='i'>
# <re.Match object; span=(27, 28), match='j'>
# <re.Match object; span=(28, 29), match='k'>
# <re.Match object; span=(29, 30), match='l'>
# <re.Match object; span=(30, 31), match='m'>
# <re.Match object; span=(31, 32), match='n'>
# <re.Match object; span=(32, 33), match='o'>
# <re.Match object; span=(33, 34), match='p'>
# <re.Match object; span=(34, 35), match='q'>
# <re.Match object; span=(35, 36), match='r'>
# <re.Match object; span=(36, 37), match='s'>
# <re.Match object; span=(37, 38), match='t'>
# <re.Match object; span=(38, 39), match='u'>
# ...

# %% [markdown]
# Does not Match Digits,Uppercase,Lowercase and Underscore

# %%
import re

# %%
pattern =re.compile(r"\W")
matches=re.finditer(pattern,text_to_search)
for match in matches:
  print(match)
# Out:
# <re.Match object; span=(0, 1), match='\n'>
# <re.Match object; span=(1, 2), match=' '>
# <re.Match object; span=(2, 3), match=' '>
# <re.Match object; span=(3, 4), match=' '>
# <re.Match object; span=(4, 5), match=' '>
# <re.Match object; span=(5, 6), match=' '>
# <re.Match object; span=(6, 7), match=' '>
# <re.Match object; span=(7, 8), match=' '>
# <re.Match object; span=(8, 9), match=' '>
# <re.Match object; span=(9, 10), match=' '>
# <re.Match object; span=(10, 11), match=' '>
# <re.Match object; span=(11, 12), match=' '>
# <re.Match object; span=(12, 13), match=' '>
# <re.Match object; span=(13, 14), match=' '>
# <re.Match object; span=(14, 15), match=' '>
# <re.Match object; span=(15, 16), match=' '>
# <re.Match object; span=(16, 17), match=' '>
# <re.Match object; span=(17, 18), match=' '>
# <re.Match object; span=(44, 45), match='\n'>
# <re.Match object; span=(45, 46), match=' '>
# <re.Match object; span=(46, 47), match=' '>
# <re.Match object; span=(47, 48), match=' '>
# ...

# %% [markdown]
# Matches all Whitespaces :tabs,newline,space

# %%
import re

# %%
pattern=re.compile(r"\s")
matches=re.finditer(pattern,text_to_search)

for match in matches:
  print(match)
# Out:
# <re.Match object; span=(0, 1), match='\n'>
# <re.Match object; span=(1, 2), match=' '>
# <re.Match object; span=(2, 3), match=' '>
# <re.Match object; span=(3, 4), match=' '>
# <re.Match object; span=(4, 5), match=' '>
# <re.Match object; span=(5, 6), match=' '>
# <re.Match object; span=(6, 7), match=' '>
# <re.Match object; span=(7, 8), match=' '>
# <re.Match object; span=(8, 9), match=' '>
# <re.Match object; span=(9, 10), match=' '>
# <re.Match object; span=(10, 11), match=' '>
# <re.Match object; span=(11, 12), match=' '>
# <re.Match object; span=(12, 13), match=' '>
# <re.Match object; span=(13, 14), match=' '>
# <re.Match object; span=(14, 15), match=' '>
# <re.Match object; span=(15, 16), match=' '>
# <re.Match object; span=(16, 17), match=' '>
# <re.Match object; span=(17, 18), match=' '>
# <re.Match object; span=(44, 45), match='\n'>
# <re.Match object; span=(45, 46), match=' '>
# <re.Match object; span=(46, 47), match=' '>
# <re.Match object; span=(47, 48), match=' '>
# ...

# %% [markdown]
# Matches other than Digits,Uppercase,Lowercase and Underscore

# %%
import re

# %%
pattern =re.compile(r"\S")
matches=re.finditer(pattern,text_to_search)
for match in matches:
  print(match)
# Out:
# <re.Match object; span=(18, 19), match='a'>
# <re.Match object; span=(19, 20), match='b'>
# <re.Match object; span=(20, 21), match='c'>
# <re.Match object; span=(21, 22), match='d'>
# <re.Match object; span=(22, 23), match='e'>
# <re.Match object; span=(23, 24), match='f'>
# <re.Match object; span=(24, 25), match='g'>
# <re.Match object; span=(25, 26), match='h'>
# <re.Match object; span=(26, 27), match='i'>
# <re.Match object; span=(27, 28), match='j'>
# <re.Match object; span=(28, 29), match='k'>
# <re.Match object; span=(29, 30), match='l'>
# <re.Match object; span=(30, 31), match='m'>
# <re.Match object; span=(31, 32), match='n'>
# <re.Match object; span=(32, 33), match='o'>
# <re.Match object; span=(33, 34), match='p'>
# <re.Match object; span=(34, 35), match='q'>
# <re.Match object; span=(35, 36), match='r'>
# <re.Match object; span=(36, 37), match='s'>
# <re.Match object; span=(37, 38), match='t'>
# <re.Match object; span=(38, 39), match='u'>
# ...

# %% [markdown]
# Matches the Word Boundary \b. This returns the word that has a space behind it

# %%
import re

# %%
pattern=re.compile(r"\bHa")
matches=re.finditer(pattern,text_to_search)
for match in matches:
  print(match)
# Out:
# <re.Match object; span=(137, 139), match='Ha'>
# <re.Match object; span=(140, 142), match='Ha'>

# %% [markdown]
# Matches that is not a word Boundary \B. This returns the word that does not has a space behind it

# %%
import re

# %%
pattern=re.compile(r"\BHa")

matches=re.finditer(pattern,text_to_search)
for match in matches:
  print(match)

# %% [markdown]
# Matching Start of the Sentence using ^ ,Search for sentence starting with ^Start

# %%
sentence='Start a sentence and then bring it to an end'

# %%
import re

# %%
pattern =re.compile(r"^Start")
matches=re.finditer(pattern,sentence)

for match in matches:
  print(match)
# Out:
# <re.Match object; span=(0, 5), match='Start'>

# %% [markdown]
# Matching End of the Sentence using$,Search for sentence ending  with end$

# %%
import re

# %%
pattern=re.compile(r"end$")
matches=re.finditer(pattern,sentence)

for match in matches:
  print(match)
# Out:
# <re.Match object; span=(41, 44), match='end'>

# %% [markdown]
# Matching End of the Sentence using$,Search for sentence ending  with the word other than end$

# %%
import re

# %%
pattern=re.compile(r"then$")
matches=re.finditer(pattern,sentence)

for match in matches:
  print(match)

# %%
text_to_search="""
                 abcdefghijklmnopqrstuvwxyz
                  ABCDEFGHIJKLMNOPQRSTUVWXYZ
                  1234567890
                  Ha Haha

                  MetaCharacters (Need to be escaped):


                  coreyms.com
                  321-555-4321

                  123.555.1234

                  Mr.Schafer
                  Mr Smith
                  Ms Davis
                  Mrs. Robinson
                  Mr. T
            """

# %% [markdown]
# Find the Phone Number.

# %%
import re

# %%
pattern=re.compile(r"\d{3}[.|-]\d{3}[.|-]\d{4}")

matches=re.finditer(pattern,text_to_search)
for match in matches:
  print(match)
# Out:
# <re.Match object; span=(282, 294), match='321-555-4321'>
# <re.Match object; span=(315, 327), match='123.555.1234'>

# %% [markdown]
# Using File Operations

# %%
with open('data.txt','r',encoding='utf-8') as f:
  contents=f.read()
pattern=re.compile(r"\d{3}[.|-]\d{3}[.|-]\d{4}")
matches=re.finditer(pattern,contents)

for match in matches:
  print(match)
# Out:
# <re.Match object; span=(12, 24), match='615-555-7164'>
# <re.Match object; span=(102, 114), match='800-555-5669'>
# <re.Match object; span=(191, 203), match='560-555-5153'>
# <re.Match object; span=(281, 293), match='900-555-9340'>
# <re.Match object; span=(378, 390), match='714-555-7405'>
# <re.Match object; span=(467, 479), match='800-555-6771'>
# <re.Match object; span=(557, 569), match='783-555-4799'>
# <re.Match object; span=(647, 659), match='516-555-4615'>
# <re.Match object; span=(740, 752), match='127-555-1867'>
# <re.Match object; span=(829, 841), match='608-555-4938'>
# <re.Match object; span=(915, 927), match='568-555-6051'>
# <re.Match object; span=(1003, 1015), match='292-555-1875'>
# <re.Match object; span=(1091, 1103), match='900-555-3205'>
# <re.Match object; span=(1180, 1192), match='614-555-1166'>
# <re.Match object; span=(1269, 1281), match='530-555-2676'>
# <re.Match object; span=(1355, 1367), match='470-555-2750'>
# ...

# %% [markdown]
# Find the Phone Number with Asterix,Dot,Hypen.

# %%
text_to_search="""
                 abcdefghijklmnopqrstuvwxyz
                  ABCDEFGHIJKLMNOPQRSTUVWXYZ
                  1234567890
                  Ha Haha

                  MetaCharacters (Need to be escaped):


                  coreyms.com
                  321-555-4321
                  327*565*4329
                  123.555.1234

                  Mr.Schafer
                  Mr Smith
                  Ms Davis
                  Mrs. Robinson
                  Mr. T
            """

# %%
import re

# %%
pattern =re.compile(r"\d{3}.\d{3}.\d{4}")

matches=re.finditer(pattern, text_to_search)

for match in matches:
  print(match)
# Out:
# <re.Match object; span=(282, 294), match='321-555-4321'>
# <re.Match object; span=(314, 326), match='327*565*4329'>
# <re.Match object; span=(346, 358), match='123.555.1234'>

# %% [markdown]
# Find the Phone Number with Dot,Hypen.

# %%
text_to_search="""
                 abcdefghijklmnopqrstuvwxyz
                  ABCDEFGHIJKLMNOPQRSTUVWXYZ
                  1234567890
                  Ha Haha

                  MetaCharacters (Need to be escaped):


                  coreyms.com
                  321-555-4321
                  327*565*4329
                  123.555.1234

                  Mr.Schafer
                  Mr Smith
                  Ms Davis
                  Mrs. Robinson
                  Mr. T
            """

# %%
import re

# %%
pattern=re.compile(r"\d{3}[.-]\d{3}[.-]\d{4}")

matches=re.finditer(pattern,text_to_search)

for match in matches:
  print(match)
# Out:
# <re.Match object; span=(251, 263), match='321-555-4321'>
# <re.Match object; span=(313, 325), match='123.555.1234'>

# %%
text_to_search="""
                 abcdefghijklmnopqrstuvwxyz
                  ABCDEFGHIJKLMNOPQRSTUVWXYZ
                  1234567890
                  Ha Haha

                  MetaCharacters (Need to be escaped):


                  coreyms.com
                  321-555-4321
                  327*565*4329
                  123.555.1234
                  800-555-4321
                  900-555-4321

                  Mr.Schafer
                  Mr Smith
                  Ms Davis
                  Mrs. Robinson
                  Mr. T
            """

# %%
import re

# %%
pattern=re.compile(r"[89]00+[.-]+\d{3}[.-]+\d{4}")

matches=re.finditer(pattern,text_to_search)
for match in matches:
  print(match)
# Out:
# <re.Match object; span=(344, 356), match='800-555-4321'>
# <re.Match object; span=(375, 387), match='900-555-4321'>

# %% [markdown]
# Extarct from data.txt file ,numbers starting with 800 and 900

# %%
import re

# %%
with open('data.txt','r',encoding='utf-8') as f:
  contents=f.read()
pattern=re.compile(r"[89]00[.-]\d{3}[.-]\d{4}")
matches=re.finditer(pattern,contents)

for match in matches:
  print(match)
# Out:
# <re.Match object; span=(102, 114), match='800-555-5669'>
# <re.Match object; span=(281, 293), match='900-555-9340'>
# <re.Match object; span=(467, 479), match='800-555-6771'>
# <re.Match object; span=(1091, 1103), match='900-555-3205'>
# <re.Match object; span=(1439, 1451), match='800-555-6089'>
# <re.Match object; span=(1790, 1802), match='800-555-7100'>
# <re.Match object; span=(2051, 2063), match='900-555-5118'>
# <re.Match object; span=(2826, 2838), match='900-555-5428'>
# <re.Match object; span=(3284, 3296), match='800-555-8810'>
# <re.Match object; span=(3971, 3983), match='900-555-9598'>
# <re.Match object; span=(4945, 4957), match='800-555-2420'>
# <re.Match object; span=(5566, 5578), match='900-555-3567'>
# <re.Match object; span=(6189, 6201), match='800-555-3216'>
# <re.Match object; span=(6889, 6901), match='900-555-7755'>
# <re.Match object; span=(7864, 7876), match='800-555-1372'>
# <re.Match object; span=(8741, 8753), match='900-555-6426'>

# %%
text_to_search="""
                 abcdefghijklmnopqrstuvwxyz
                  ABCDEFGHIJKLMNOPQRSTUVWXYZ
                  1234567890
                  Ha Haha

                  MetaCharacters (Need to be escaped):


                  coreyms.com
                  321-555-4321
                  327*565*4329
                  123.555.1234
                  800-555-4321
                  900-555-4321

                  Mr. Schafer
                  Mr Smith
                  Ms Davis
                  Mrs. Robinson
                  Mr. T

                  cat
                  mat
                  pat
                  bat
            """

# %%
import re

# %%
pattern=re.compile(r"[^b]at")

matches=re.finditer(pattern,text_to_search)

for match in matches:
  print(match)
# Out:
# <re.Match object; span=(547, 550), match='cat'>
# <re.Match object; span=(569, 572), match='mat'>
# <re.Match object; span=(591, 594), match='pat'>

# %% [markdown]
# Matching a Phone Number

# %%
text_to_search="""
                 abcdefghijklmnopqrstuvwxyz
                  ABCDEFGHIJKLMNOPQRSTUVWXYZ
                  1234567890
                  Ha Haha

                  MetaCharacters (Need to be escaped):


                  coreyms.com
                  321-555-4321
                  327*565*4329
                  123.555.1234
                  800-555-4321
                  900-555-4321

                  Mr. Schafer
                  Mr Smith
                  Ms Davis
                  Mrs. Robinson
                  Mr. T

                  cat
                  mat
                  pat
                  bat
            """

# %%
import re

# %%
pattern=re.compile(r"\d{3}.\d{3}.\d{4}")
matches=re.finditer(pattern,text_to_search)

for match in matches:
  print(match)
# Out:
# <re.Match object; span=(251, 263), match='321-555-4321'>
# <re.Match object; span=(282, 294), match='327*565*4329'>
# <re.Match object; span=(313, 325), match='123.555.1234'>
# <re.Match object; span=(344, 356), match='800-555-4321'>
# <re.Match object; span=(375, 387), match='900-555-4321'>

# %% [markdown]
#   To match these names that start with Mr.
#
#   Mr.Schafer
#
#   Mr Smith
#
#   Mr. T

# %%
text_to_search="""
                 abcdefghijklmnopqrstuvwxyz
                  ABCDEFGHIJKLMNOPQRSTUVWXYZ
                  1234567890
                  Ha Haha

                  MetaCharacters (Need to be escaped):


                  coreyms.com
                  321-555-4321
                  327*565*4329
                  123.555.1234
                  800-555-4321
                  900-555-4321

                  Mr. Schafer
                  Mr Smith
                  Ms Davis
                  Mrs. Robinson
                  Mr. T

                  cat
                  mat
                  pat
                  bat
            """

# %%
import re

# %%
pattern=re.compile(r"Mr\.? [A-z]\w*")
matches=re.finditer(pattern,text_to_search)

for match in matches:
  print(match)
# Out:
# <re.Match object; span=(407, 418), match='Mr. Schafer'>
# <re.Match object; span=(437, 445), match='Mr Smith'>
# <re.Match object; span=(523, 528), match='Mr. T'>

# %% [markdown]
#   To match these names that start with Mr.
#
#   Mr.Schafer
#
#   Mr Smith
#
#   Mr. T
#
#   Mrs. Robinson

# %%
import re

# %%
pattern=re.compile(r"(Mr|Mrs)\.?\s[A-Z]\w*")
matches=re.finditer(pattern,text_to_search)

for match in matches:
  print(match)
# Out:
# <re.Match object; span=(407, 418), match='Mr. Schafer'>
# <re.Match object; span=(437, 445), match='Mr Smith'>
# <re.Match object; span=(491, 504), match='Mrs. Robinson'>
# <re.Match object; span=(523, 528), match='Mr. T'>

# %%
text_to_search="""
                 abcdefghijklmnopqrstuvwxyz
                  ABCDEFGHIJKLMNOPQRSTUVWXYZ
                  1234567890
                  Ha Haha

                  MetaCharacters (Need to be escaped):


                  coreyms.com
                  321-555-4321
                  327*565*4329
                  123.555.1234
                  800-555-4321
                  900-555-4321

                  Mr. Schafer
                  Mr Smith
                  Ms Davis
                  Mrs. Robinson
                  Mr. T

                  cat
                  mat
                  pat
                  bat
            """

# %%
emails='''

      CoreyMSchafer@gmail.com

       corey.schafer@university.edu

       corey-321-schafer@my-work.net
    '''

# %%
import re

# %%
pattern=re.compile(r"[a-zA-Z-\.0-9]+@+[a-zA-Z-\.]+[a-zA-Z]")
matches=re.finditer(pattern,emails)

for match in matches:
  print(match)
# Out:
# <re.Match object; span=(8, 31), match='CoreyMSchafer@gmail.com'>
# <re.Match object; span=(40, 68), match='corey.schafer@university.edu'>
# <re.Match object; span=(77, 106), match='corey-321-schafer@my-work.net'>

# %%
urls='''
     https://www.google.com
     http://coreyms.com
     https://youtube.com
     https://www.nasa.gov
'''

# %%
import re

# %%
pattern=re.compile(r"(http|https)://[a-zA-Z\.]+[a-zA-Z\.]+[a-zA-Z]+")
matches=re.finditer(pattern,urls)

for match in matches:
  print(match)
# Out:
# <re.Match object; span=(10, 32), match='https://www.google.com'>
# <re.Match object; span=(40, 58), match='http://coreyms.com'>
# <re.Match object; span=(64, 83), match='https://youtube.com'>
# <re.Match object; span=(89, 109), match='https://www.nasa.gov'>

# %% [markdown]
# **match**-  This looks for the given string at the begning of the Sentence.

# %%
sentence="Start a sentence and then bring it to an end"

# %%
pattern=re.compile(r"Start")

matches=re.match(pattern,sentence)
print(matches)
# Out:
# <re.Match object; span=(0, 5), match='Start'>

# %%
Sentence="Start a sentence and then bring it to an end"

# %%
import re

# %%
pattern=re.compile(r"sentence")

matches=re.match(pattern,Sentence)
print(matches)
# Out:
# None

# %% [markdown]
# **search**- This will look if the given word exists in the entire String

# %% [markdown]
# Sentence="Start a sentence and then bring it to an end"

# %%
import re

# %%
Sentence="Start a sentence and then bring it to an end"

# %%
pattern =re.compile(r'sentence')

matches=re.search(pattern,Sentence)
print(matches)
# Out:
# <re.Match object; span=(8, 16), match='sentence'>

# %%
import re

# %%
Sentence="Start a sentence and then bring it to an end"

# %%
pattern =re.compile(r"Hello")

matches=re.search(pattern,Sentence)
print(matches)
# Out:
# None

# %% [markdown]
# Using Flags to make it CASESENSITIVE

# %%
import re

# %%
Sentence="Start a sentence and then bring it to an end"

# %%
pattern=re.compile(r"start",re.IGNORECASE)

matches=re.search(pattern,Sentence)

print(matches)
# Out:
# <re.Match object; span=(0, 5), match='Start'>

# %% [markdown]
# Extracting Dates in different format from the text.
